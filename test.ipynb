# %%
import pickle
from matplotlib import pyplot as plt

dat = pickle.load(open('new_testset.pkl', 'rb'))

print(dat[10][0])
N = len(dat[10][1])
idx, rates, chord, melody = dat[10]
plt.figure(figsize=(10, 3))
plt.plot(range(N), rates, label='Transition rates')
#plt.plot(range(N), melody)
plt.show()

plt.figure(figsize=(10, 3))
plt.plot(range(N), chord, label='Transition rates')
#plt.plot(range(N), melody)
plt.show()


plt.figure(figsize=(10, 3))
plt.plot(range(1, N), melody, label='Transition rates')
#plt.plot(range(N), melody)
plt.show()
# Out:
# 011
